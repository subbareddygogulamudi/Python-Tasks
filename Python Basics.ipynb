# %% [markdown]
# 1.What is a keyword in python? Write list of keywords in python.

# %% [markdown]
# Keywords are some of special words that has a predefined work assigned to it.
# There are total of 35 keywords are there.They are
#
# if,else,elif,for,while,True,False,global,lambda,None,and,or,not,continue,break,pass,raise,try,return,
# import,del,in,as,is,def,with,yeild,assert,async,await,class,except,finally,from,non local

# %% [markdown]
# 2.What is the difference between an integer and a string? Give an example of each by creating variables age (integer) and name (string).

# %% [markdown]
# Integer is a whole numbers.
# While,String is a sequence of characters.
#
# age=21
# name="subba reddy"

# %% [markdown]
# 3.What is a Datatype and write list of Datatypes of python.

# %% [markdown]
# Data type that specifies the type of value a variable.
# Here are the list of data types.They are
# Numerical-->int,float,complex
# boolean-->True,False
# sequence-->str,list,tuple
# mapping-->dict
# sets-->set
# none-->None

# %% [markdown]
# 4.Given the string text = "Python", what will text[0] return? What about text[5]?

# %%
text="Python"

# %%
text[0]
# Out:
# 'P'

# %%
text[5]
# Out:
# 'n'

# %% [markdown]
# 5.For the string word = "Hello", what will word[-1] return? Explain what negative indexing means.

# %%
word="Hello"

# %%
word[-1]
# Out:
# 'o'

# %% [markdown]
# # negative indexing means allows us to access characters from the end of the string
# * the last character is at index -1
# * the second lat is -2 and so on like this.

# %% [markdown]
# 6.What happens if you try to access text[10] in the string text = "Python"? Write the code and describe the result.

# %%
text="Python"

# %%
text[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 text[10]
#
# IndexError: string index out of range

# %%
# the index is out of range that's why it's showing error.

# %% [markdown]
# 7.Write Python code to convert the string "42" to an integer and print the result.

# %%
s="42"
int(s)
# Out:
# 42

# %% [markdown]
# 8.What will happen if you try to convert the string "hello" to an integer using int("hello")? Explain the result.

# %%
a="hello"
int("hello")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 a="hello"
# ----> 2 int("hello")
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
# hello is not a number,so python doesn't know how to convert it.

# %% [markdown]
# 9.What is a variable in python? Write what are rules to define a variable.

# %% [markdown]
# It is a location in memory used to store the data.
# Rules to define a variable
# 1.No practicial length limit min character is one.
# 2.Cannot be used a reserved keyword.
# 3.it can be combination of alphabets A to Z or a to z ,digits(1,infinite) and under score(_) only.
# 4.should start with (_)or alphabets only.

# %% [markdown]
# 10.Create a variable score with the value 100 and print it. Then change score to 200 and print it again.

# %%
score=100

# %%
print(score)
# Out:
# 100

# %%
score=200

# %%
print(score)
# Out:
# 200

# %% [markdown]
# 11.Write Python code to create two variables, a and b, with values 5 and 10, and print their sum.

# %%
a=5
b=10
print(a+b)
# Out:
# 15

# %% [markdown]
# 12.Given the string phrase = "Python is fun", write Python code to:
#    Extract the word "Python" using slicing
#    Extract the word "fun" using slicing. Explain what the numbers in phrase[0:6] mean

# %%
s="python is fun"
s[0:6]
# Out:
# 'python'

# %%
s[10:]
# Out:
# 'fun'

# %% [markdown]
# explanation:
# this is called string slicing
# phrase [start:stop:step]
# here,the initial index start at 0 and reaches till index 5 (applies n-1 rules)
